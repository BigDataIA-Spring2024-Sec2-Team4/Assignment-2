# %%
! pip install boto3 sqlalchemy
# Out:
# ...
#   Using cached jmespath-1.0.1-py3-none-any.whl (20 kB)
# ...
#    ---------------------------------------- 0.0/139.3 kB ? eta -:--:--
#    -- ------------------------------------- 10.2/139.3 kB ? eta -:--:--
#    ----------------- ---------------------- 61.4/139.3 kB 1.1 MB/s eta 0:00:01
#    ---------------------------------------- 139.3/139.3 kB 2.1 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/12.0 MB ? eta -:--:--
#    - -------------------------------------- 0.4/12.0 MB 12.9 MB/s eta 0:00:01
#    --- ------------------------------------ 1.0/12.0 MB 12.7 MB/s eta 0:00:01
#    ----- ---------------------------------- 1.6/12.0 MB 12.4 MB/s eta 0:00:01
#    ------ --------------------------------- 2.1/12.0 MB 12.1 MB/s eta 0:00:01
#    -------- ------------------------------- 2.4/12.0 MB 11.8 MB/s eta 0:00:01
#    ---------- ----------------------------- 3.0/12.0 MB 11.4 MB/s eta 0:00:01
#    ----------- ---------------------------- 3.4/12.0 MB 11.5 MB/s eta 0:00:01
# ...

# %%
import os

os.environ['AWS_ACCESS_KEY_ID'] = 'AKIAZQ3DOEV5MIL5FAV5'
os.environ['AWS_SECRET_ACCESS_KEY'] = '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'

# %%
import boto3
from botocore.exceptions import NoCredentialsError
from sqlalchemy import create_engine
import pandas as pd


# Function to upload files to AWS S3 bucket
def upload_to_s3(file_path, bucket_name, object_name):
    s3 = boto3.client('s3')
    
    try:
        s3.upload_file(file_path, bucket_name, object_name)
        print(f"{file_path} uploaded to {bucket_name}/{object_name}")
        return True
    except NoCredentialsError:
        print("Credentials not available")
        return False

# Example usage
if __name__ == "__main__":
    # Replace these with your actual AWS and Snowflake details
    AWS_ACCESS_KEY_ID = 'access_id'
    AWS_SECRET_ACCESS_KEY = 'aws_key'
    bucket_name = 'bucket'

    user = 'User_Name'
    password = 'PASSWORD'
    account = 'ACCOUNT'


    snowflake_connection_string = f'snowflake+sqlalchemy://{user}:{password}@{account}.snowflakecomputing.com/{database}?warehouse={warehouse}'

    # Print AWS credentials for debugging
    print(f"AWS_ACCESS_KEY_ID: {AWS_ACCESS_KEY_ID}")
    print(f"AWS_SECRET_ACCESS_KEY: {AWS_SECRET_ACCESS_KEY}")

    # Upload CSV file to S3
    csv_file_path = 'C:/ProgramData/MySQL/MySQL Server 8.0/Uploads/bigdata_demo.csv'
    csv_object_name = 'scrappeddata.csv'
    upload_to_s3(csv_file_path, bucket_name, csv_object_name)

    # Upload text files from Grobid and PyPDF to S3

    grobid_folder_path = 'C:/ProgramData/MySQL/MySQL Server 8.0/Uploads/PyPDF'
    s3_object_prefix = 'PyPDF_'

    for file_name in os.listdir(grobid_folder_path):
        if file_name.endswith(('.txt',)):
            local_file_path = os.path.join(grobid_folder_path, file_name)
            s3_object_name = f"{s3_object_prefix}{file_name}"
            upload_to_s3(local_file_path, bucket_name, s3_object_name)





































    # # Create a DataFrame with structured metadata
    # metadata = {'column1': [value1], 'column2': [value2], 'link_to_txt_file': [f's3://{bucket_name}/{grobid_object_name}']}
    # metadata_df = pd.DataFrame(metadata)

    # # Upload metadata to Snowflake
    # upload_to_snowflake(metadata_df, snowflake_connection_string)
# Out:
# AWS_ACCESS_KEY_ID: AKIAZQ3DOEV5MIL5FAV5
# AWS_SECRET_ACCESS_KEY: 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
# C:/ProgramData/MySQL/MySQL Server 8.0/Uploads/bigdata_demo.csv uploaded to cfadatabase/scrappeddata.csv
# C:/ProgramData/MySQL/MySQL Server 8.0/Uploads/PyPDF\Grobid_RR_2024_l1_combined.txt uploaded to cfadatabase/PyPDF_Grobid_RR_2024_l1_combined.txt
# C:/ProgramData/MySQL/MySQL Server 8.0/Uploads/PyPDF\Grobid_RR_2024_l2_combined.txt uploaded to cfadatabase/PyPDF_Grobid_RR_2024_l2_combined.txt
# C:/ProgramData/MySQL/MySQL Server 8.0/Uploads/PyPDF\Grobid_RR_2024_l3_combined.txt uploaded to cfadatabase/PyPDF_Grobid_RR_2024_l3_combined.txt
# C:/ProgramData/MySQL/MySQL Server 8.0/Uploads/PyPDF\PyPDF_RR_2024_l1_combined.txt uploaded to cfadatabase/PyPDF_PyPDF_RR_2024_l1_combined.txt
# C:/ProgramData/MySQL/MySQL Server 8.0/Uploads/PyPDF\PyPDF_RR_2024_l2_combined.txt uploaded to cfadatabase/PyPDF_PyPDF_RR_2024_l2_combined.txt
# ...

# %%
# This code is for uploading metadata to snowflake

#Importing warnings and dependencies
import warnings
from sqlalchemy import create_engine, Column, Integer, String
from sqlalchemy.ext.declarative import declarative_base
from dotenv import load_dotenv
import os

# Loading the environment variables from .env file
load_dotenv()

# Ignore warnings
warnings.filterwarnings("ignore")

# Database connection details
DB_USERNAME = os.getenv("DB_USERNAME")
DB_PASSWORD = os.getenv("DB_PASSWORD")
DATABASE_NAME = os.getenv("DATABASE_NAME")
SQLALCHEMY_DATABASE_URL = f"mysql+pymysql://{DB_USERNAME}:{DB_PASSWORD}@localhost/{DATABASE_NAME}"

# Creating SQLAlchemy engine for MySQL
mysql_engine = create_engine(SQLALCHEMY_DATABASE_URL)

# Creating MySQL table
Base = declarative_base()

class CFADataTable(Base):
    __tablename__ = "Metadata_table"

    id = Column(Integer, primary_key=True, index=True)
    Index= Column(String(255))
    c = Column(Integer)
    Language = Column(String(50))
    Version = Column(Integer)
    Encoding = Column(String(500))
    File_Size = Column(Integer)

    def __repr__(self):
        return f"<MetadataTable(id={self.id}, Name_of_the_topic={self.Name_of_the_topic}, Year={self.Year})>"

# Creating MySQL table in the database
Base.metadata.create_all(bind=mysql_engine)

# Creating Snowflake engine
snowflake_engine = create_engine(
    'snowflake://{user}:{password}@{account}/'.format(
        user=os.getenv("SNOWFLAKE_USER"),
        password=os.getenv("SNOWFLAKE_PASSWORD"),
        account=os.getenv("SNOWFLAKE_ACCOUNT"),
    )
)

# Snowflake queries
create_database_query = "CREATE OR REPLACE DATABASE META_DATABASE;"
create_table_query = """CREATE OR REPLACE TABLE METADATA_TABLE (
    "Index" STRING(255),
    "c" STRING,
    "Language" STRING(50),
    "Version" NUMBER,
    "Encoding" STRING(500),
    "File_Size" NUMBER
    );"""


create_warehouse = """CREATE OR REPLACE WAREHOUSE METADATA
    WITH WAREHOUSE_SIZE='X-SMALL'
    AUTO_SUSPEND = 180
    AUTO_RESUME = TRUE
    INITIALLY_SUSPENDED=TRUE;"""

create_stage = """CREATE STAGE DUMMY DIRECTORY = (ENABLE = true);"""
upload_to_stage = """PUT 'file://C:/ProgramData/MySQL/MySQL Server 8.0/Uploads/metadata.csv' @DUMMY;"""

copy_stage_to_table = """COPY INTO METADATA_TABLE
FROM @META_DATABASE.public.dummy
FILE_FORMAT = (type = csv field_optionally_enclosed_by='"' skip_header = 1)
PATTERN = '.*metadata.csv.gz'
ON_ERROR = 'CONTINUE';
"""

try:
    # MySQL operations
    mysql_connection = mysql_engine.connect()
    mysql_connection.close()
    
    # Snowflake operations
    snowflake_connection = snowflake_engine.connect()
    results = snowflake_connection.execute(create_database_query)
    results = snowflake_connection.execute(create_table_query)
    results = snowflake_connection.execute(create_warehouse)
    results = snowflake_connection.execute("USE DATABASE META_DATABASE")
    results = snowflake_connection.execute(create_stage)
    results = snowflake_connection.execute(upload_to_stage)
    results = snowflake_connection.execute(copy_stage_to_table)

finally:
    print("Done")
    snowflake_connection.close()
    snowflake_engine.dispose()
# Out:
# Done
