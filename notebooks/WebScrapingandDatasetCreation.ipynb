# %% [markdown]
# #Web Scraping and Dataset Creation
#
# This script effectively adapts a Scrapy project to run in a Jupyter notebook environment. By installing necessary packages, adjusting the asyncio settings for Jupyter, adding the project path to the system path, importing and applying project settings, and finally running the spider, it allows for seamless web scraping directly from a notebook. This approach is particularly useful for development, testing, and educational purposes where the full IDE setup might not be available or preferred.

# %%
#Installs scrapy, scrapy-playwright, and playwright packages,
#which are essential for running Scrapy spiders and integrating Playwright for JavaScript-rendered page scraping
# !pip install scrapy
# !pip install scrapy-playwright
# !pip install playwright
# !playwright install

# %%
#Applies nest_asyncio to allow the asynchronous loop to run in the Jupyter environment,
#which is necessary because Jupyter already runs an event loop.
import nest_asyncio
nest_asyncio.apply()
from scrapy.crawler import CrawlerProcess

# %%
#Imports modules required for setting up and running a Scrapy spider.
#This includes Scrapy's CrawlerProcess for running spiders, Settings for configuring the spider, and other utilities.

import sys
import os
from importlib import import_module
from scrapy.settings import Settings
import scrapy
from scrapy_playwright.page import PageMethod
from scrapy.http import HtmlResponse
from scrapy.crawler import CrawlerProcess


#Adds the project directory to Python's path to ensure modules from the Scrapy project can be imported.
#This step is crucial for Colab to recognize Scrapy project's structure and files.
project_path = os.path.abspath(os.path.join('/content/drive/MyDrive/Pwspider'))
if project_path not in sys.path:
    sys.path.append(project_path)


# Import your project's settings module from a.py
settings_module_path = 'Pwspider.settings'  # Adjusted for a.py

imported_settings = import_module(settings_module_path)


# Convert imported settings to a Scrapy Settings object
settings = Settings()
for setting_name in dir(imported_settings):
    if setting_name.isupper():
        setting_value = getattr(imported_settings, setting_name)
        settings.set(setting_name, setting_value)

# %%
#Initializes and starts CrawlerProcess with the configured settings and the specified spider.
#This command begins the scraping process.

process = CrawlerProcess(settings=settings)
process.crawl('pwspidey')
process.start()
# Out:
# INFO:scrapy.utils.log:Scrapy 2.11.1 started (bot: Pwspider)
# 2024-02-16 02:44:11 [scrapy.utils.log] INFO: Scrapy 2.11.1 started (bot: Pwspider)
# INFO:scrapy.utils.log:Versions: lxml 4.9.4.0, libxml2 2.10.3, cssselect 1.2.0, parsel 1.8.1, w3lib 2.1.2, Twisted 23.10.0, Python 3.10.12 (main, Nov 20 2023, 15:14:05) [GCC 11.4.0], pyOpenSSL 24.0.0 (OpenSSL 3.2.1 30 Jan 2024), cryptography 42.0.2, Platform Linux-6.1.58+-x86_64-with-glibc2.35
# 2024-02-16 02:44:11 [scrapy.utils.log] INFO: Versions: lxml 4.9.4.0, libxml2 2.10.3, cssselect 1.2.0, parsel 1.8.1, w3lib 2.1.2, Twisted 23.10.0, Python 3.10.12 (main, Nov 20 2023, 15:14:05) [GCC 11.4.0], pyOpenSSL 24.0.0 (OpenSSL 3.2.1 30 Jan 2024), cryptography 42.0.2, Platform Linux-6.1.58+-x86_64-with-glibc2.35
# INFO:scrapy.addons:Enabled addons:
# []
# 2024-02-16 02:44:11 [scrapy.addons] INFO: Enabled addons:
# []
# DEBUG:scrapy.utils.log:Using reactor: twisted.internet.asyncioreactor.AsyncioSelectorReactor
# 2024-02-16 02:44:11 [scrapy.utils.log] DEBUG: Using reactor: twisted.internet.asyncioreactor.AsyncioSelectorReactor
# DEBUG:scrapy.utils.log:Using asyncio event loop: asyncio.unix_events._UnixSelectorEventLoop
# 2024-02-16 02:44:11 [scrapy.utils.log] DEBUG: Using asyncio event loop: asyncio.unix_events._UnixSelectorEventLoop
# INFO:scrapy.extensions.telnet:Telnet Password: 3f0a3ab16a6e6ec2
# 2024-02-16 02:44:11 [scrapy.extensions.telnet] INFO: Telnet Password: 3f0a3ab16a6e6ec2
# INFO:scrapy.middleware:Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.memusage.MemoryUsage',
#  'scrapy.extensions.feedexport.FeedExporter',
#  'scrapy.extensions.logstats.LogStats']
# 2024-02-16 02:44:11 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.memusage.MemoryUsage',
#  'scrapy.extensions.feedexport.FeedExporter',
#  'scrapy.extensions.logstats.LogStats']
# INFO:scrapy.crawler:Overridden settings:
# {'BOT_NAME': 'Pwspider',
#  'CONCURRENT_REQUESTS': 225,
#  'CONCURRENT_REQUESTS_PER_DOMAIN': 16,
#  'CONCURRENT_REQUESTS_PER_IP': 16,
#  'DOWNLOAD_DELAY': 0.5,
#  'FEED_EXPORT_ENCODING': 'utf-8',
#  'NEWSPIDER_MODULE': 'Pwspider.spiders',
#  'REQUEST_FINGERPRINTER_IMPLEMENTATION': '2.7',
#  'ROBOTSTXT_OBEY': True,
#  'SPIDER_MODULES': ['Pwspider.spiders'],
#  'TWISTED_REACTOR': 'twisted.internet.asyncioreactor.AsyncioSelectorReactor'}
# 2024-02-16 02:44:11 [scrapy.crawler] INFO: Overridden settings:
# {'BOT_NAME': 'Pwspider',
#  'CONCURRENT_REQUESTS': 225,
#  'CONCURRENT_REQUESTS_PER_DOMAIN': 16,
#  'CONCURRENT_REQUESTS_PER_IP': 16,
#  'DOWNLOAD_DELAY': 0.5,
#  'FEED_EXPORT_ENCODING': 'utf-8',
#  'NEWSPIDER_MODULE': 'Pwspider.spiders',
#  'REQUEST_FINGERPRINTER_IMPLEMENTATION': '2.7',
#  'ROBOTSTXT_OBEY': True,
#  'SPIDER_MODULES': ['Pwspider.spiders'],
#  'TWISTED_REACTOR': 'twisted.internet.asyncioreactor.AsyncioSelectorReactor'}
# INFO:scrapy.middleware:Enabled downloader middlewares:
# ['scrapy.downloadermiddlewares.robotstxt.RobotsTxtMiddleware',
#  'scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
#  'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
#  'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
#  'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware',
#  'Pwspider.middlewares.DebugLoggingMiddleware',
#  'scrapy.downloadermiddlewares.retry.RetryMiddleware',
#  'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
#  'scrapy.downloadermiddlewares.httpcompression.HttpCompressionMiddleware',
#  'scrapy.downloadermiddlewares.redirect.RedirectMiddleware',
#  'scrapy.downloadermiddlewares.cookies.CookiesMiddleware',
#  'scrapy.downloadermiddlewares.httpproxy.HttpProxyMiddleware',
#  'scrapy.downloadermiddlewares.stats.DownloaderStats']
# 2024-02-16 02:44:12 [scrapy.middleware] INFO: Enabled downloader middlewares:
# ['scrapy.downloadermiddlewares.robotstxt.RobotsTxtMiddleware',
#  'scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
#  'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
#  'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
#  'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware',
#  'Pwspider.middlewares.DebugLoggingMiddleware',
#  'scrapy.downloadermiddlewares.retry.RetryMiddleware',
#  'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
#  'scrapy.downloadermiddlewares.httpcompression.HttpCompressionMiddleware',
#  'scrapy.downloadermiddlewares.redirect.RedirectMiddleware',
#  'scrapy.downloadermiddlewares.cookies.CookiesMiddleware',
#  'scrapy.downloadermiddlewares.httpproxy.HttpProxyMiddleware',
#  'scrapy.downloadermiddlewares.stats.DownloaderStats']
# INFO:scrapy.middleware:Enabled spider middlewares:
# ['scrapy.spidermiddlewares.httperror.HttpErrorMiddleware',
#  'scrapy.spidermiddlewares.offsite.OffsiteMiddleware',
#  'scrapy.spidermiddlewares.referer.RefererMiddleware',
#  'scrapy.spidermiddlewares.urllength.UrlLengthMiddleware',
#  'scrapy.spidermiddlewares.depth.DepthMiddleware']
# 2024-02-16 02:44:12 [scrapy.middleware] INFO: Enabled spider middlewares:
# ['scrapy.spidermiddlewares.httperror.HttpErrorMiddleware',
#  'scrapy.spidermiddlewares.offsite.OffsiteMiddleware',
#  'scrapy.spidermiddlewares.referer.RefererMiddleware',
#  'scrapy.spidermiddlewares.urllength.UrlLengthMiddleware',
#  'scrapy.spidermiddlewares.depth.DepthMiddleware']
# INFO:scrapy.middleware:Enabled item pipelines:
# []
# 2024-02-16 02:44:12 [scrapy.middleware] INFO: Enabled item pipelines:
# []
# INFO:scrapy.core.engine:Spider opened
# 2024-02-16 02:44:12 [scrapy.core.engine] INFO: Spider opened
# INFO:scrapy.extensions.logstats:Crawled 0 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2024-02-16 02:44:12 [scrapy.extensions.logstats] INFO: Crawled 0 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# INFO:scrapy.extensions.telnet:Telnet console listening on 127.0.0.1:6023
# 2024-02-16 02:44:12 [scrapy.extensions.telnet] INFO: Telnet console listening on 127.0.0.1:6023
# INFO:scrapy-playwright:Starting download handler
# 2024-02-16 02:44:12 [scrapy-playwright] INFO: Starting download handler
# INFO:scrapy-playwright:Starting download handler
# 2024-02-16 02:44:12 [scrapy-playwright] INFO: Starting download handler
# DEBUG:pwspidey:Processing request: https://www.cfainstitute.org/robots.txt
# 2024-02-16 02:44:17 [pwspidey] DEBUG: Processing request: https://www.cfainstitute.org/robots.txt
# DEBUG:pwspidey:Received response: https://www.cfainstitute.org/robots.txt - Status: 200
# 2024-02-16 02:44:17 [pwspidey] DEBUG: Received response: https://www.cfainstitute.org/robots.txt - Status: 200
# DEBUG:scrapy.core.engine:Crawled (200) <GET https://www.cfainstitute.org/robots.txt> (referer: None)
# 2024-02-16 02:44:17 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.cfainstitute.org/robots.txt> (referer: None)
# DEBUG:pwspidey:Processing request: https://www.cfainstitute.org/en/membership/professional-development/refresher-readings#sort=%40refreadingcurriculumyear%20descending
# 2024-02-16 02:44:17 [pwspidey] DEBUG: Processing request: https://www.cfainstitute.org/en/membership/professional-development/refresher-readings#sort=%40refreadingcurriculumyear%20descending
# INFO:scrapy-playwright:Launching browser firefox
# 2024-02-16 02:44:17 [scrapy-playwright] INFO: Launching browser firefox
# INFO:scrapy-playwright:Browser firefox launched
# 2024-02-16 02:44:18 [scrapy-playwright] INFO: Browser firefox launched
# DEBUG:scrapy-playwright:Browser context started: 'default' (persistent=False, remote=False)
# 2024-02-16 02:44:18 [scrapy-playwright] DEBUG: Browser context started: 'default' (persistent=False, remote=False)
# DEBUG:scrapy-playwright:[Context=default] New page created, page count is 1 (1 for all contexts)
# 2024-02-16 02:44:20 [scrapy-playwright] DEBUG: [Context=default] New page created, page count is 1 (1 for all contexts)
# DEBUG:scrapy-playwright:[Context=default] Request: <GET https://www.cfainstitute.org/en/membership/professional-development/refresher-readings> (resource type: document)
# 2024-02-16 02:44:21 [scrapy-playwright] DEBUG: [Context=default] Request: <GET https://www.cfainstitute.org/en/membership/professional-development/refresher-readings> (resource type: document)
# DEBUG:scrapy-playwright:[Context=default] Response: <200 https://www.cfainstitute.org/en/membership/professional-development/refresher-readings>
# 2024-02-16 02:44:22 [scrapy-playwright] DEBUG: [Context=default] Response: <200 https://www.cfainstitute.org/en/membership/professional-development/refresher-readings>
# DEBUG:scrapy-playwright:[Context=default] Request: <GET https://uxpatterns.cfainstitute.org/globalbundles/styles/global.css?v=KdNELzb1y2vxWM8E2EL6QwKRgtgsmoCqgS-UIJMeWjM1> (resource type: stylesheet, referrer: https://www.cfainstitute.org/)
# 2024-02-16 02:44:23 [scrapy-playwright] DEBUG: [Context=default] Request: <GET https://uxpatterns.cfainstitute.org/globalbundles/styles/global.css?v=KdNELzb1y2vxWM8E2EL6QwKRgtgsmoCqgS-UIJMeWjM1> (resource type: stylesheet, referrer: https://www.cfainstitute.org/)
# DEBUG:scrapy-playwright:[Context=default] Request: <GET https://www.cfainstitute.org/bundles/styles/cfa?v=125x6ywLABoBFfNSTbyfK-syoLKkEibipfJjFGZtuxw1> (resource type: stylesheet, referrer: https://www.cfainstitute.org/en/membership/professional-development/refresher-readings)
# 2024-02-16 02:44:23 [scrapy-playwright] DEBUG: [Context=default] Request: <GET https://www.cfainstitute.org/bundles/styles/cfa?v=125x6ywLABoBFfNSTbyfK-syoLKkEibipfJjFGZtuxw1> (resource type: stylesheet, referrer: https://www.cfainstitute.org/en/membership/professional-development/refresher-readings)
# DEBUG:scrapy-playwright:[Context=default] Request: <GET https://www.cfainstitute.org/layouts/system/VisitorIdentification.js> (resource type: script, referrer: https://www.cfainstitute.org/en/membership/professional-development/refresher-readings)
# 2024-02-16 02:44:23 [scrapy-playwright] DEBUG: [Context=default] Request: <GET https://www.cfainstitute.org/layouts/system/VisitorIdentification.js> (resource type: script, referrer: https://www.cfainstitute.org/en/membership/professional-development/refresher-readings)
# DEBUG:scrapy-playwright:[Context=default] Request: <GET https://assets.adobedtm.com/ca679de7f940/5199d11943bc/launch-750c66e2ab45.min.js> (resource type: script, referrer: https://www.cfainstitute.org/)
# 2024-02-16 02:44:23 [scrapy-playwright] DEBUG: [Context=default] Request: <GET https

# DEBUG:scrapy-playwright:[Context=default] Response: <200 https://static.cloud.coveo.com/searchui/v2.10089/js/CoveoJsSearch.Lazy.min.js>
# 2024-02-16 02:44:25 [scrapy-playwright] DEBUG: [Context=default] Response: <200 https://static.cloud.coveo.com/searchui/v2.10089/js/CoveoJsSearch.Lazy.min.js>
# DEBUG:scrapy-playwright:[Context=default] Response: <200 https://static.cloud.coveo.com/coveoforsitecore/ui/v0.55.8/js/CoveoForSitecore.Lazy.min.js>
# 2024-02-16 02:44:25 [scrapy-playwright] DEBUG: [Context=default] Response: <200 https://static.cloud.coveo.com/coveoforsitecore/ui/v0.55.8/js/CoveoForSitecore.Lazy.min.js>
# DEBUG:scrapy-playwright:[Context=default] Response: <200 https://static.cloud.coveo.com/searchui/v2.10089/js/cultures/en.js>
# 2024-02-16 02:44:25 [scrapy-playwright] DEBUG: [Context=default] Response: <200 https://static.cloud.coveo.com/searchui/v2.10089/js/cultures/en.js>
# DEBUG:scrapy-playwright:[Context=default] Response: <200 https://static.cloudflareinsights.com/beacon.min.js/v84a3a4012de94ce1a686ba8c167c359c1696973893317>
# 2024-02-16 02:44:25 [scrapy-playwright] DEBUG: [Context=default] Response: <200 https://static.cloudflareinsights.com/beacon.min.js/v84a3a4012de94ce1a686ba8c167c359c1696973893317>
# DEBUG:scrapy-playwright:[Context=default] Response: <200 https://www.googletagmanager.com/gtm.js?id=GTM-WLD6ZF9>
# 2024-02-16 02:44:25 [scrapy-playwright] DEBUG: [Context=default] Response: <200 https://www.googletagmanager.com/gtm.js?id=GTM-WLD6ZF9>
# DEBUG:scrapy-playwright:[Context=default] Request: <GET https://www.googletagmanager.com/gtag/js?id=G-FD9VH0194T&l=dataLayer&cx=c> (resource type: script, referrer: https://www.cfainstitute.org/)
# 2024-02-16 02:44:25 [scrapy-playwright] DEBUG: [Context=default] Request: <GET https://www.googletagmanager.com/gtag/js?id=G-FD9VH0194T&l=dataLayer&cx=c> (resource type: script, referrer: https://www.cfainstitute.org/)
# DEBUG:scrapy-playwright:[Context=default] Request: <GET https://cdn.mouseflow.com/projects/b6179523-a747-4a5b-b08b-dd62fa5ec0d6.js> (resource type: script, referrer: https://www.cfainstitute.org/)
# 2024-02-16 02:44:26 [scrapy-playwright] DEBUG: [Context=default] Request: <GET https://cdn.mouseflow.com/projects/b6179523-a747-4a5b-b08b-dd62fa5ec0d6.js> (resource type: script, referrer: https://www.cfainstitute.org/)
# DEBUG:scrapy-playwright:[Context=default] Response: <200 https://fonts.googleapis.com/css2?family=Lato:wght@400;700;900&display=swap>
# 2024-02-16 02:44:27 [scrapy-playwright] DEBUG: [Context=default] Response: <200 https://fonts.googleapis.com/css2?family=Lato:wght@400;700;900&display=swap>
# DEBUG:scrapy-playwright:[Context=default] Request: <GET https://uxpatterns.cfainstitute.org/Content/img/loading.png> (resource type: image, referrer: https://uxpatterns.cfainstitute.org/globalbundles/styles/global.css?v=KdNELzb1y2vxWM8E2EL6QwKRgtgsmoCqgS-UIJMeWjM1)
# 2024-02-16 02:44:27 [scrapy-playwright] DEBUG: [Context=default] Request: <GET https://uxpatterns.cfainstitute.org/Content/img/loading.png> (resource type: image, referrer: https://uxpatterns.cfainstitute.org/globalbundles/styles/global.css?v=KdNELzb1y2vxWM8E2EL6QwKRgtgsmoCqgS-UIJMeWjM1)
# DEBUG:scrapy-playwright:[Context=default] Request: <GET https://fonts.gstatic.com/s/lato/v24/S6uyw4BMUTPHvxk.ttf> (resource type: font, referrer: https://fonts.googleapis.com/)
# 2024-02-16 02:44:27 [scrapy-playwright] DEBUG: [Context=default] Request: <GET https://fonts.gstatic.com/s/lato/v24/S6uyw4BMUTPHvxk.ttf> (resource type: font, referrer: https://fonts.googleapis.com/)
# DEBUG:scrapy-playwright:[Context=default] Request: <GET https://fonts.gstatic.com/s/lato/v24/S6u9w4BMUTPHh6UVew8.ttf> (resource type: font, referrer: https://fonts.googleapis.com/)
# 2024-02-16 02:44:27 [scrapy-playwright] DEBUG: [Context=default] Request: <GET https://fonts.gstatic.com/s/lato/v24/S6u9w4BMUTPHh6UVew8.ttf> (resource type: font, referrer: https://fonts.googleapis.com/)
# DEBUG:scrapy-playwright:[Context=default] Request: <GET https://static.cloud.coveo.com/coveo.analytics.js/2/coveoua.js> (resource type: script, referrer: https://www.cfainstitute.org/)
# 2024-02-16 02:44:27 [scrapy-playwright] DEBUG: [Context=default] Request: <GET https://static.cloud.coveo.com/coveo.analytics.js/2/coveoua.js> (resource type: script, referrer: https://www.cfainstitute.org/)
# DEBUG:scrapy-playwright:[Context=default] Response: <200 https://fonts.googleapis.com/css?family=Lato:300,400,700>
# 2024-02-16 02:44:27 [scrapy-playwright] DEBUG: [Context=default] Response: <200 https://fonts.googleapis.com/css?family=Lato:300,400,700>
# DEBUG:scrapy-playwright:[Context=default] Request: <GET https://uxpatterns.cfainstitute.org/Content/img/bootstrap/linkedin-inverted.svg> (resource type: image, referrer: https://uxpatterns.cfainstitute.org/globalbundles/styles/global.css?v=KdNELzb1y2vxWM8E2EL6QwKRgtgsmoCqgS-UIJMeWjM1)
# 2024-02-16 02:44:27 [scrapy-playwright] DEBUG: [Context=default] Request: <GET https://uxpatterns.cfainstitute.org/Content/img/bootstrap/linkedin-inverted.svg> (resource type: image, referrer: https://uxpatterns.cfainstitute.org/globalbundles/styles/global.css?v=KdNELzb1y2vxWM8E2EL6QwKRgtgsmoCqgS-UIJMeWjM1)
# DEBUG:scrapy-playwright:[Context=default] Request: <GET https://uxpatterns.cfainstitute.org/Content/img/bootstrap/facebook-inverted.svg> (resource type: image, referrer: https://uxpatterns.cfainstitute.org/globalbundles/styles/global.css?v=KdNELzb1y2vxWM8E2EL6QwKRgtgsmoCqgS-UIJMeWjM1)
# 2024-02-16 02:44:27 [scrapy-playwright] DEBUG: [Context=default] Request: <GET https://uxpatterns.cfainstitute.org/Content/img/bootstrap/facebook-inverted.svg> (resource type: image, referrer: https://uxpatterns.cfainstitute.org/globalbundles/styles/global.css?v=KdNELzb1y2vxWM8E2EL6QwKRgtgsmoCqgS-UIJMeWjM1)
# DEBUG:scrapy-playwright:[Context=default] Request: <GET https://uxpatterns.cfainstitute.org/Content/img/bootstrap/twitter-inverted.svg> (resource type: image, referrer: https://uxpatterns.cfainstitute.org/globalbundles/styles/global.css?v=KdNELzb1y2vxWM8E2EL6QwKRgtgsmoCqgS-UIJMeWjM1)
# 2024-02-16 02:44:27 [scrapy-playwright] DEBUG: [Context=default] Request: <GET https://uxpatterns.cfainstitute.org/Content/img/bootstrap/twitter-inverted.svg> (resource type: image, referrer: https://uxpatterns.cfainstitute.org/globalbundles/styles/global.css?v=KdNELzb1y2vxWM8E2EL6QwKRgtgsmoCqgS-UIJMeWjM1)
# DEBUG:scrapy-playwright:[Context=default] Request: <GET https://uxpatterns.cfainstitute.org/Content/img/bootstrap/wechat-inverted.svg> (resource type: image, referrer: https://uxpatterns.cfainstitute.org/globalbundles/styles/global.css?v=KdNELzb1y2vxWM8E2EL6QwKRgtgsmoCqgS-UIJMeWjM1)
# 2024-02-16 02:44:27 [scrapy-playwright] DEBUG: [Context=default] Request: <GET https://uxpatterns.cfainstitute.org/Content/img/bootstrap/wechat-inverted.svg> (resource type: image, referrer: https://uxpatterns.cfainstitute.org/globalbundles/styles/global.css?v=KdNELzb1y2vxWM8E2EL6QwKRgtgsmoCqgS-UIJMeWjM1)
# DEBUG:scrapy-playwright:[Context=default] Request: <GET https://uxpatterns.cfainstitute.org/Content/img/bootstrap/weibo-inverted.svg> (resource type: image, referrer: https://uxpatterns.cfainstitute.org/globalbundles/styles/global.css?v=KdNELzb1y2vxWM8E2EL6QwKRgtgsmoCqgS-UIJMeWjM1)
# 2024-02-16 02:44:27 [scrapy-playwright] DEBUG: [Context=default] Request: <GET https://uxpatterns.cfainstitute.org/Content/img/bootstrap/weibo-inverted.svg> (resource type: image, referrer: https://uxpatterns.cfainstitute.org/globalbundles/styles/global.css?v=KdNELzb1y2vxWM8E2EL6QwKRgtgsmoCqgS-UIJMeWjM1)
# DEBUG:scrapy-playwright:[Context=default] Request: <GET https://fonts.gstatic.com/s/lato/v24/S6u9w4BMUTPHh50Xew8.ttf> (resource type: font, referrer: https://fonts.googleapis.com/)
# 2024-02-16 02:44:28 [scrapy-playwright] DEBUG: [Context=default] Request: <GET https://fonts.gstatic.com/s/lato/v24/S6u9w4BMUTPHh50Xew8.ttf> (resource type: font, referrer: https://fonts.googleapis.com/)
# DEBUG:scrapy-playwright:[Context=default] Response: <200 https://www.googletagmanager.com/gtag/js?id=G-FD9VH0194T&l=dataLayer&cx=c>
# 2024-02-16 02:44:28 [scrapy-playwright] DEBUG: [Context=default] Response: <200 https://www.googletagmanager.com/gtag/js?id=G-FD9VH0194T&l=dataLayer&cx=c>
# DEBUG:scrapy-playwright:[Context=default] Request: <GET https://fonts.gstatic.com/s/lato/v24/S6uyw4BMUTPHjx4wWw.ttf> (resource type: font, referrer: https://fonts.googleapis.com/)
# 2024-02-16 02:44:28 [scrapy-playwright] DEBUG: [Context=default] Request: <GET https://fonts.gstatic.com/s/lato/v24/S6uyw4BMUTPHjx4wWw.ttf> (resource type: font, referrer: https://fonts.googleapis.com/)
# DEBUG:scrapy-playwright:[Context=default] Request: <GET https://fonts.gstatic.com/s/lato/v24/S6u9w4BMUTPHh6UVSwiPHA.ttf> (resource type: font, referrer: https://fonts.googleapis.com/)
# 2024-02-16 02:44:28 [scrapy-playwright] DEBUG: [Context=default] Request: <GET https://fonts.gstatic.com/s/lato/v24/S6u9w4BMUTPHh6UVSwiPHA.ttf> (resource type: font, referrer: https://fonts.googleapis.com/)
# DEBUG:scrapy-playwright:[Context=default] Request: <GET https://dpm.demdex.net/id?d_visid_ver=5.5.0&d_fieldgroup=MC&d_rtbd=json&d_ver=2&d_orgid=192334FA53DAAC620A490D44%40AdobeOrg&d_nsid=0&ts=1708051466364> (resource type: xhr, referrer: https://www.cfainstitute.org/)
# 2024-02-16 02:44:28 [scrapy-playwright] DEBUG: [Context=default] Request: <GET https://dpm.demdex.net/id?d_visid_ver=5.5.0&d_fieldgroup=MC&d_rtbd=json&d_ver=2&d_orgid=192334FA53DAAC620A490D44%40AdobeOrg&d_nsid=0&ts=1708051466364> (resource type: xhr, referrer: https://www.cfainstitute.org/)
# DEBUG:scrapy-playwright:[Context=default] Request: <GET https://assets.adobedtm.com/extensions/EPef068a8d6dd34a43866d9a80cc98baab/AppMeasurement.min.js> (resource type: script, referrer: https://www.cfainstitute.org/)
# 2024-02-16 02:44:28 [scrapy-playwright] DEBUG: [Context=default] Request: <GET https://assets.adobedtm.com/extensions/EPef068a8d6dd34a43866d9a80cc98baab/AppMeasurement.min.js> (resource type: script, referrer: https://www.cfainstitute.org/)
# DEBUG:scrapy-playwright:[Context=default] Request: <GET https://assets.adobedtm.com/extensions/EPef068a8d6dd34a43866d9a80cc98baab/AppMeasurement_Module_ActivityMap.min.js> (resource type: script, referrer: https://www.cfainstitute.org/)
# 2024-02-16 02:44:28 [scrapy-playwright] DEBUG: [Context=default] Request: <GET https
referrer: https://www.cfainstitute.org/)
# DEBUG:scrapy-playwright:[Context=default] Request: <GET https://cm.everesttech.net/cm/dd?d_uuid=47339856708565275880570092966437267682> (resource type: image, referrer: https://www.cfainstitute.org/)
# 2024-02-16 02:44:30 [scrapy-playwright] DEBUG: [Context=default] Request: <GET https://cm.everesttech.net/cm/dd?d_uuid=47339856708565275880570092966437267682> (resource type: image, referrer: https://www.cfainstitute.org/)
# DEBUG:scrapy-playwright:[Context=default] Request: <GET https://smetrics.cfainstitute.org/b/ss/cfaprod/1/JS-2.25.0-LDQM/s23714757926859?AQB=1&ndh=1&pf=1&t=16%2F1%2F2024%202%3A44%3A28%205%200&mid=47363939042882836510567474735008307717&aamlh=11&ce=UTF-8&pageName=membership%3Aprofessional-development%3Arefresher-readings&g=https%3A%2F%2Fwww.cfainstitute.org%2Fen%2Fmembership%2Fprofessional-development%2Frefresher-readings%23sort%3D%2540refreadingcurriculumyear%2520descending&c.&getTimeSinceLastVisit=2.0.1&inList=3.0&formatTime=2.0&getNewRepeat=3.0.1&apl=4.0&getPreviousValue=3.0.1&getVisitNum=4.2.1&endOfDatePeriod=1.2&getValOnce=3.0.1&.c&cc=USD&ch=public%3Amembership&server=www.cfainstitute.org&events=event18&aamb=6G1ynYcLPuiQxYZrsz_pkqfLG9yMXBpb2zX5dvJdYQJzPXImdj0y&c1=membership&v1=https%3A%2F%2Fwww.cfainstitute.org%2Fen%2Fmembership%2Fprofessional-development%2Frefresher-readings%23sort%3D%2540refreadingcurriculumyear%2520descending&c2=professional-development&c3=refresher-readings&v8=D%3Dc8&c9=New&v9=D%3Dc9&v19=D%3Dc22&v20=D%3Dc24&v21=D%3Dc20&v22=D%3Dc21&c23=New%20Visitor&v23=D%3Dc25&v24=D%3Dc26&v25=D%3Dc27&c29=1&v29=D%3Dc29&v30=D%3Dc23&c32=www.cfainstitute.org&v32=%2B1&c33=membership%3Aprofessional-development%3Arefresher-readings&c39=membership%3Aprofessional-development%3Arefresher-readings-prod&v45=www.cfainstitute.org&c57=NA&v75=scrapy%2F2.11.1%20%28%2Bhttps%3A%2F%2Fscrapy.org%29&v77=sitecore&v87=NA&v89=membership%3Aprofessional-development%3Arefresher-readings-prod&s=1280x720&c=24&j=1.6&v=N&k=Y&bw=1280&bh=720&mcorgid=192334FA53DAAC620A490D44%40AdobeOrg&AQE=1> (resource type: image, referrer: https://www.cfainstitute.org/)
# ...
#     extracted: _SelfResultT | Failure = result.result()
#   File "/usr/lib/python3.10/asyncio/futures.py", line 201, in result
#     raise self._exception.with_traceback(self._exception_tb)
#   File "/usr/lib/python3.10/asyncio/tasks.py", line 232, in __step
#     result = coro.send(None)
#   File "/usr/local/lib/python3.10/dist-packages/scrapy_playwright/handler.py", line 314, in _download_request
#     page = await self._create_page(request=request, spider=spider)
#   File "/usr/local/lib/python3.10/dist-packages/scrapy_playwright/handler.py", line 236, in _create_page
#     ctx_wrapper = await self._create_browser_context(
#   File "/usr/local/lib/python3.10/dist-packages/scrapy_playwright/handler.py", line 196, in _create_browser_context
#     context = await self.browser.new_context(**context_kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/playwright/async_api/_generated.py", line 14308, in new_context
#     await self._impl_obj.new_context(
#   File "/usr/local/lib/python3.10/dist-packages/playwright/_impl/_browser.py", line 127, in new_context
#     channel = await self._channel.send("newContext", params)
#   File "/usr/local/lib/python3.10/dist-packages/playwright/_impl/_connection.py", line 63, in send
#     return await self._connection.wrap_api_call(
#   File "/usr/local/lib/python3.10/dist-packages/playwright/_impl/_connection.py", line 495, in wrap_api_call
#     return await cb()
#   File "/usr/local/lib/python3.10/dist-packages/playwright/_impl/_connection.py", line 101, in inner_send
#     result = next(iter(done)).result()
#   File "/usr/lib/python3.10/asyncio/futures.py", line 201, in result
#     raise self._exception.with_traceback(self._exception_tb)
# Exception: Connection closed while reading from the driver
# 2024-02-16 02:59:38 [scrapy.core.scraper] ERROR: Error downloading <GET https://www.cfainstitute.org/membership/professional-development/refresher-readings/option-replication-put-call-parity>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/twisted/internet/defer.py", line 1996, in _inlineCallbacks
#     result = context.run(
#   File "/usr/local/lib/python3.10/dist-packages/twisted/python/failure.py", line 519, in throwExceptionIntoGenerator
#     return g.throw(self.type, self.value, self.tb)
#   File "/usr/local/lib/python3.10/dist-packages/scrapy/core/downloader/middleware.py", line 54, in process_request
#     return (yield download_func(request=request, spider=spider))
#   File "/usr/local/lib/python3.10/dist-packages/twisted/internet/defer.py", line 1248, in adapt
#     extracted: _SelfResultT | Failure = result.result()
#   File "/usr/lib/python3.10/asyncio/futures.py", line 201, in result
#     raise self._exception.with_traceback(self._exception_tb)
#   File "/usr/lib/python3.10/asyncio/tasks.py", line 232, in __step
#     result = coro.send(None)
#   File "/usr/local/lib/python3.10/dist-packages/scrapy_playwright/handler.py", line 314, in _download_request
#     page = await self._create_page(request=request, spider=spider)
#   File "/usr/local/lib/python3.10/dist-packages/scrapy_playwright/handler.py", line 236, in _create_page
#     ctx_wrapper = await self._create_browser_context(
#   File "/usr/local/lib/python3.10/dist-packages/scrapy_playwright/handler.py", line 196, in _create_browser_context
#     context = await self.browser.new_context(**context_kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/playwright/async_api/_generated.py", line 14308, in new_context
#     await self._impl_obj.new_context(
#   File "/usr/local/lib/python3.10/dist-packages/playwright/_impl/_browser.py", line 127, in new_context
#     channel = await self._channel.send("newContext", params)
#   File "/usr/local/lib/python3.10/dist-packages/playwright/_impl/_connection.py", line 63, in send
#     return await self._connection.wrap_api_call(
#   File "/usr/local/lib/python3.10/dist-packages/playwright/_impl/_connection.py", line 495, in wrap_api_call
#     return await cb()
#   File "/usr/local/lib/python3.10/dist-packages/playwright/_impl/_connection.py", line 101, in inner_send
#     result = next(iter(done)).result()
#   File "/usr/lib/python3.10/asyncio/futures.py", line 201, in result
#     raise self._exception.with_traceback(self._exception_tb)
# Exception: Connection closed while reading from the driver
# INFO:scrapy.extensions.feedexport:Stored csv feed (16 items) in: data.csv
# 2024-02-16 02:59:38 [scrapy.extensions.feedexport] INFO: Stored csv feed (16 items) in: data.csv
# INFO:scrapy.statscollectors:Dumping Scrapy stats:
# {'downloader/exception_count': 207,
#  'downloader/exception_type_count/builtins.Exception': 191,
#  'downloader/exception_type_count/playwright._impl._errors.TargetClosedError': 16,
#  'downloader/request_bytes': 98779,
#  'downloader/request_count': 225,
#  'downloader/request_method_count/GET': 225,
#  'downloader/response_bytes': 2096695,
#  'downloader/response_count': 18,
#  'downloader/response_status_count/200': 18,
#  'dupefilter/filtered': 1,
#  'elapsed_time_seconds': 925.85697,
#  'feedexport/success_count/FileFeedStorage': 1,
#  'finish_reason': 'shutdown',
#  'finish_time': datetime.datetime(2024, 2, 16, 2, 59, 38, 114396, tzinfo=datetime.timezone.utc),
#  'httpcompression/response_bytes': 570,
#  'httpcompression/response_count': 1,
#  'item_scraped_count': 16,
#  'log_count/DEBUG': 5114,
#  'log_count/ERROR': 207,
#  'log_count/INFO': 31,
#  'log_count/WARNING': 205,
#  'memusage/max': 350478336,
#  'memusage/startup': 152092672,
#  'playwright/context_count': 1,
#  'playwright/context_count/max_concurrent': 1,
#  'playwright/context_count/persistent/False': 1,
#  'playwright/context_count/remote/False': 1,
#  'playwright/page_count': 33,
#  'playwright/page_count/max_concurrent': 33,
#  'playwright/request_count': 2433,
#  'playwright/request_count/method/GET': 2228,
#  'playwright/request_count/method/POST': 205,
#  'playwright/request_count/navigation': 63,
#  'playwright/request_count/resource_type/document': 63,
#  'playwright/request_count/resource_type/fetch': 100,
#  'playwright/request_count/resource_type/font': 136,
#  'playwright/request_count/resource_type/image': 566,
#  'playwright/request_count/resource_type/other': 36,
#  'playwright/request_count/resource_type/script': 1229,
#  'playwright/request_count/resource_type/stylesheet': 200,
#  'playwright/request_count/resource_type/xhr': 103,
#  'playwright/response_count': 2364,
#  'playwright/response_count/method/GET': 2188,
#  'playwright/response_count/method/POST': 176,
#  'playwright/response_count/resource_type/document': 59,
#  'playwright/response_count/resource_type/fetch': 96,
#  'playwright/response_count/resource_type/font': 136,
#  'playwright/response_count/resource_type/image': 554,
#  'playwright/response_count/resource_type/other': 36,
#  'playwright/response_count/resource_type/script': 1205,
#  'playwright/response_count/resource_type/stylesheet': 200,
#  'playwright/response_count/resource_type/xhr': 78,
#  'request_depth_max': 1,
#  'response_received_count': 18,
#  'robotstxt/request_count': 1,
#  'robotstxt/response_count': 1,
#  'robotstxt/response_status_count/200': 1,
#  'scheduler/dequeued': 224,
#  'scheduler/dequeued/memory': 224,
#  'scheduler/enqueued': 224,
#  'scheduler/enqueued/memory': 224,
#  'start_time': datetime.datetime(2024, 2, 16, 2, 44, 12, 257426, tzinfo=datetime.timezone.utc)}
# 2024-02-16 02:59:38 [scrapy.statscollectors] INFO: Dumping Scrapy stats:
# {'downloader/exception_count': 207,
#  'downloader/exception_type_count/builtins.Exception': 191,
#  'downloader/exception_type_count/playwright._impl._errors.TargetClosedError': 16,
#  'downloader/request_bytes': 98779,
#  'downloader/request_count': 225,
#  'downloader/request_method_count/GET': 225,
#  'downloader/response_bytes': 2096695,
#  'downloader/response_count': 18,
#  'downloader/response_status_count/200': 18,
#  'dupefilter/filtered': 1,
#  'elapsed_time_seconds': 925.85697,
#  'feedexport/success_count/FileFeedStorage': 1,
#  'finish_reason': 'shutdown',
#  'finish_time': datetime.datetime(2024, 2, 16, 2, 59, 38, 114396, tzinfo=datetime.timezone.utc),
#  'httpcompression/response_bytes': 570,
#  'httpcompression/response_count': 1,
#  'item_scraped_count': 16,
#  'log_count/DEBUG': 5114,
#  'log_count/ERROR': 207,
#  'log_count/INFO': 31,
#  'log_count/WARNING': 205,
#  'memusage/max': 350478336,
#  'memusage/startup': 152092672,
#  'playwright/context_count': 1,
#  'playwright/context_count/max_concurrent': 1,
#  'playwright/context_count/persistent/False': 1,
#  'playwright/context_count/remote/False': 1,
#  'playwright/page_count': 33,
#  'playwright/page_count/max_concurrent': 33,
#  'playwright/request_count': 2433,
#  'playwright/request_count/method/GET': 2228,
#  'playwright/request_count/method/POST': 205,
#  'playwright/request_count/navigation': 63,
#  'playwright/request_count/resource_type/document': 63,
#  'playwright/request_count/resource_type/fetch': 100,
#  'playwright/request_count/resource_type/font': 136,
#  'playwright/request_count/resource_type/image': 566,
#  'playwright/request_count/resource_type/other': 36,
#  'playwright/request_count/resource_type/script': 1229,
#  'playwright/request_count/resource_type/stylesheet': 200,
#  'playwright/request_count/resource_type/xhr': 103,
#  'playwright/response_count': 2364,
#  'playwright/response_count/method/GET': 2188,
#  'playwright/response_count/method/POST': 176,
#  'playwright/response_count/resource_type/document': 59,
#  'playwright/response_count/resource_type/fetch': 96,
#  'playwright/response_count/resource_type/font': 136,
#  'playwright/response_count/resource_type/image': 554,
#  'playwright/response_count/resource_type/other': 36,
#  'playwright/response_count/resource_type/script': 1205,
#  'playwright/response_count/resource_type/stylesheet': 200,
#  'playwright/response_count/resource_type/xhr': 78,
#  'request_depth_max': 1,
#  'response_received_count': 18,
#  'robotstxt/request_count': 1,
#  'robotstxt/response_count': 1,
#  'robotstxt/response_status_count/200': 1,
#  'scheduler/dequeued': 224,
#  'scheduler/dequeued/memory': 224,
#  'scheduler/enqueued': 224,
#  'scheduler/enqueued/memory': 224,
#  'start_time': datetime.datetime(2024, 2, 16, 2, 44, 12, 257426, tzinfo=datetime.timezone.utc)}
# INFO:scrapy.core.engine:Spider closed (shutdown)
# 2024-02-16 02:59:38 [scrapy.core.engine] INFO: Spider closed (shutdown)
# INFO:scrapy-playwright:Closing download handler
# 2024-02-16 02:59:38 [scrapy-playwright] INFO: Closing download handler
# INFO:scrapy-playwright:Closing download handler
# 2024-02-16 02:59:38 [scrapy-playwright] INFO: Closing download handler
# INFO:scrapy-playwright:Closing browser
# 2024-02-16 02:59:38 [scrapy-playwright] INFO: Closing browser
# WARNING:asyncio:pipe closed by peer or os.write(pipe, data) raised exception.
# 2024-02-16 02:59:38 [asyncio] WARNING: pipe closed by peer or os.write(pipe, data) raised exception.
# ERROR:scrapy.utils.signal:Error caught on signal handler: <bound method DownloadHandlers._close of <scrapy.core.downloader.handlers.DownloadHandlers object at 0x789aa30ed6f0>>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/twisted/internet/defer.py", line 1996, in _inlineCallbacks
#     result = context.run(
#   File "/usr/local/lib/python3.10/dist-packages/twisted/python/failure.py", line 519, in throwExceptionIntoGenerator
#     return g.throw(self.type, self.value, self.tb)
#   File "/usr/local/lib/python3.10/dist-packages/scrapy/core/downloader/handlers/__init__.py", line 92, in _close
#     yield dh.close()
#   File "/usr/local/lib/python3.10/dist-packages/twisted/internet/defer.py", line 1996, in _inlineCallbacks
#     result = context.run(
#   File "/usr/local/lib/python3.10/dist-packages/twisted/python/failure.py", line 519, in throwExceptionIntoGenerator
#     return g.throw(self.type, self.value, self.tb)
#   File "/usr/local/lib/python3.10/dist-packages/scrapy_playwright/handler.py", line 293, in close
#     yield deferred_from_coro(self._close())
#   File "/usr/local/lib/python3.10/dist-packages/twisted/internet/defer.py", line 1248, in adapt
#     extracted: _SelfResultT | Failure = result.result()
#   File "/usr/lib/python3.10/asyncio/futures.py", line 201, in result
#     raise self._exception.with_traceback(self._exception_tb)
#   File "/usr/lib/python3.10/asyncio/tasks.py", line 232, in __step
#     result = coro.send(None)
#   File "/usr/local/lib/python3.10/dist-packages/scrapy_playwright/handler.py", line 300, in _close
#     await self.browser.close()
#   File "/usr/local/lib/python3.10/dist-packages/playwright/async_api/_generated.py", line 14581, in close
#     return mapping.from_maybe_impl(await self._impl_obj.close(reason=reason))
#   File "/usr/local/lib/python3.10/dist-packages/playwright/_impl/_browser.py", line 189, in close
#     raise e
#   File "/usr/local/lib/python3.10/dist-packages/playwright/_impl/_browser.py", line 186, in close
#     await self._channel.send("close", {"reason": reason})
#   File "/usr/local/lib/python3.10/dist-packages/playwright/_impl/_connection.py", line 63, in send
#     return await self._connection.wrap_api_call(
#   File "/usr/local/lib/python3.10/dist-packages/playwright/_impl/_connection.py", line 495, in wrap_api_call
#     return await cb()
#   File "/usr/local/lib/python3.10/dist-packages/playwright/_impl/_connection.py", line 101, in inner_send
#     result = next(iter(done)).result()
#   File "/usr/lib/python3.10/asyncio/futures.py", line 201, in result
#     raise self._exception.with_traceback(self._exception_tb)
# Exception: Connection closed while reading from the driver
# 2024-02-16 02:59:38 [scrapy.utils.signal] ERROR: Error caught on signal handler: <bound method DownloadHandlers._close of <scrapy.core.downloader.handlers.DownloadHandlers object at 0x789aa30ed6f0>>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/twisted/internet/defer.py", line 1996, in _inlineCallbacks
#     result = context.run(
#   File "/usr/local/lib/python3.10/dist-packages/twisted/python/failure.py", line 519, in throwExceptionIntoGenerator
#     return g.throw(self.type, self.value, self.tb)
#   File "/usr/local/lib/python3.10/dist-packages/scrapy/core/downloader/handlers/__init__.py", line 92, in _close
#     yield dh.close()
#   File "/usr/local/lib/python3.10/dist-packages/twisted/internet/defer.py", line 1996, in _inlineCallbacks
#     result = context.run(
#   File "/usr/local/lib/python3.10/dist-packages/twisted/python/failure.py", line 519, in throwExceptionIntoGenerator
#     return g.throw(self.type, self.value, self.tb)
#   File "/usr/local/lib/python3.10/dist-packages/scrapy_playwright/handler.py", line 293, in close
#     yield deferred_from_coro(self._close())
#   File "/usr/local/lib/python3.10/dist-packages/twisted/internet/defer.py", line 1248, in adapt
#     extracted: _SelfResultT | Failure = result.result()
#   File "/usr/lib/python3.10/asyncio/futures.py", line 201, in result
#     raise self._exception.with_traceback(self._exception_tb)
#   File "/usr/lib/python3.10/asyncio/tasks.py", line 232, in __step
#     result = coro.send(None)
#   File "/usr/local/lib/python3.10/dist-packages/scrapy_playwright/handler.py", line 300, in _close
#     await self.browser.close()
#   File "/usr/local/lib/python3.10/dist-packages/playwright/async_api/_generated.py", line 14581, in close
#     return mapping.from_maybe_impl(await self._impl_obj.close(reason=reason))
#   File "/usr/local/lib/python3.10/dist-packages/playwright/_impl/_browser.py", line 189, in close
#     raise e
#   File "/usr/local/lib/python3.10/dist-packages/playwright/_impl/_browser.py", line 186, in close
#     await self._channel.send("close", {"reason": reason})
#   File "/usr/local/lib/python3.10/dist-packages/playwright/_impl/_connection.py", line 63, in send
#     return await self._connection.wrap_api_call(
#   File "/usr/local/lib/python3.10/dist-packages/playwright/_impl/_connection.py", line 495, in wrap_api_call
#     return await cb()
#   File "/usr/local/lib/python3.10/dist-packages/playwright/_impl/_connection.py", line 101, in inner_send
#     result = next(iter(done)).result()
#   File "/usr/lib/python3.10/asyncio/futures.py", line 201, in result
#     raise self._exception.with_traceback(self._exception_tb)
# Exception: Connection closed while reading from the driver
