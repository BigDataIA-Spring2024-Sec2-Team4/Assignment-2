# %% [markdown]
# # Web Scraping and Dataset Creation
#
# This Jupyter notebook explains how to run the scrapy project on notebook environment.
# To run this in a notebook environment, launch the notebook in the scrapy-playwright environment.
# To create a virtual environment, run the below command on terminal and launch the notebook.

# %%
# !pip install -r spiders/requirements.txt
# Out:
# ...
#
# [notice] A new release of pip is available: 23.3.2 -> 24.0
# [notice] To update, run: pip install --upgrade pip

# %%
#Applies nest_asyncio to allow the asynchronous loop to run in the Jupyter environment, 
#which is necessary because Jupyter already runs an event loop.

import nest_asyncio
nest_asyncio.apply()
from scrapy.crawler import CrawlerProcess

# %%
import sys
import os
from importlib import import_module
from scrapy.settings import Settings
import scrapy
from scrapy_playwright.page import PageMethod
from scrapy.http import HtmlResponse



# Add your Scrapy project's directory to the Python path
project_path = os.path.abspath(os.path.join('~/Pwspider'))
if project_path not in sys.path:
    sys.path.append(project_path)

# Import your project's settings module from a.py
settings_module_path = 'Pwspider.settings'  
imported_settings = import_module(settings_module_path)


# Convert imported settings to a Scrapy Settings object
settings = Settings()
for setting_name in dir(imported_settings):
    if setting_name.isupper():
        setting_value = getattr(imported_settings, setting_name)
        settings.set(setting_name, setting_value)

# Now you can access your settings
print(settings.get('BOT_NAME'))

# To use these settings with CrawlerProcess
from scrapy.crawler import CrawlerProcess

process = CrawlerProcess(settings=settings)
process.crawl('pwspidey')  
process.start()  # Blocks here until the crawling is finished
# Out:
# 2024-02-15 20:39:56 [scrapy.utils.log] INFO: Scrapy 2.11.0 started (bot: Pwspider)
# 2024-02-15 20:39:56 [scrapy.utils.log] INFO: Versions: lxml 5.1.0.0, libxml2 2.12.3, cssselect 1.2.0, parsel 1.8.1, w3lib 2.1.2, Twisted 22.10.0, Python 3.11.4 (main, Jul  5 2023, 08:54:11) [Clang 14.0.6 ], pyOpenSSL 24.0.0 (OpenSSL 3.2.1 30 Jan 2024), cryptography 42.0.2, Platform macOS-14.3-arm64-arm-64bit
# 2024-02-15 20:39:56 [scrapy.addons] INFO: Enabled addons:
# []
# 2024-02-15 20:39:56 [scrapy.utils.log] DEBUG: Using reactor: twisted.internet.asyncioreactor.AsyncioSelectorReactor
# 2024-02-15 20:39:56 [scrapy.utils.log] DEBUG: Using asyncio event loop: asyncio.unix_events._UnixSelectorEventLoop
# 2024-02-15 20:39:56 [scrapy.extensions.telnet] INFO: Telnet Password: 0285e31b7c149e8d
# 2024-02-15 20:39:56 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.memusage.MemoryUsage',
# ...
