# %%
# !pip install diagrams
# Out:
# Collecting diagrams
#   Downloading diagrams-0.23.4-py3-none-any.whl (24.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 35.4 MB/s eta 0:00:00
# Requirement already satisfied: graphviz<0.21.0,>=0.13.2 in /usr/local/lib/python3.10/dist-packages (from diagrams) (0.20.1)
# Requirement already satisfied: jinja2<4.0,>=2.10 in /usr/local/lib/python3.10/dist-packages (from diagrams) (3.1.3)
# Collecting typed-ast<2.0.0,>=1.5.4 (from diagrams)
#   Downloading typed_ast-1.5.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (824 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 824.7/824.7 kB 28.3 MB/s eta 0:00:00
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2<4.0,>=2.10->diagrams) (2.1.5)
# Installing collected packages: typed-ast, diagrams
# Successfully installed diagrams-0.23.4 typed-ast-1.5.5

# %%
from diagrams import Diagram, Node, Cluster, Edge
from diagrams.custom import Custom
from diagrams.generic.database import SQL
from diagrams.aws.storage import S3
from diagrams.onprem.database import Mysql
from diagrams.onprem.database import Mongodb
from diagrams.onprem.database import Oracle
from urllib.request import urlretrieve
from diagrams.onprem.workflow import Nifi
from diagrams.generic.storage import Storage
from diagrams.aws.storage import SimpleStorageServiceS3Bucket

# Import custom icons for XML, PDF, spider middleware, spider, GROBID, Playwright, and scheduler
with Diagram("Assignment 2 diagram", show=False, direction="LR", outformat="png") as print:


  # Create a pipeline icon
  pipeline_URL = "https://th.bing.com/th/id/OIP.6ZBVwzr3ArMOwJcOk9rWlgAAAA?rs=1&pid=ImgDetMain"
  pipeline_icon_path = "pipeline.png"
  urlretrieve(pipeline_URL, pipeline_icon_path)
  pipeline = Custom("\nItem Pipeline",pipeline_icon_path, pipeline_label="pipeline", fontsize="12")

  # Create a XML icon
  xml_URL = "https://th.bing.com/th/id/R.0847379b195915d194de337931e10d85?rik=VVtR845fo%2bJX%2fg&pid=ImgRaw&r=0"
  xml_icon_path = "xml.png"
  urlretrieve(xml_URL, xml_icon_path)
  xml = Custom("\nXML",xml_icon_path, xml_label="XML", fontsize="12")

# Create a PDF icon
  pdf_URL = "https://th.bing.com/th/id/OIP.MlxOIkjg7MyE4TK4bE7MHAHaHa?rs=1&pid=ImgDetMain"
  pdf_icon_path = "pdf.png"
  urlretrieve(pdf_URL, pdf_icon_path)
  pdf = Custom("\nPDF",pdf_icon_path, pdf_label="PDF", fontsize="12")

# Create a spyder icon
  spyder_URL = "https://th.bing.com/th/id/R.61ad722a5d0f3e4c9e2ecafc61a695a2?rik=ueWX2t%2be6q4GqQ&riu=http%3a%2f%2fwww.kanenote.org%2fblog%2fwp-content%2f2018%2f02%2fSpyder_logo.png&ehk=RQtg5eSF8sOO%2bpoDK%2fyh9bOg%2f7R1pUspQhDIjXjKCCw%3d&risl=&pid=ImgRaw&r=0"
  spyder_icon_path = "spyder.png"
  urlretrieve(spyder_URL, spyder_icon_path)
  spyder = Custom("\nSpyder",spyder_icon_path, spyder_label="spyder", fontsize="12")

# Create a grobid icon
  grobid_URL = "https://th.bing.com/th/id/OIP.KiYmBpp_mxQnnukN5q5VOAHaHa?rs=1&pid=ImgDetMain"
  grobid_icon_path = "grobid.png"
  urlretrieve(grobid_URL, grobid_icon_path)
  grobid = Custom("\nGrobid",grobid_icon_path, grobid_label="Grobid", fontsize="12")

# Create a playwright icon
  playwright_URL = "https://blog.apify.com/content/images/2022/01/playwright-logo.png"
  playwright_icon_path = "playwright.png"
  urlretrieve(playwright_URL, playwright_icon_path)
  playwright = Custom("\nPlaywright",playwright_icon_path, playwright_label="playwright", fontsize="12")

# Create a scheduler icon
  scheduler_URL = "https://th.bing.com/th/id/OIP.g0iZlca5ndxC4hkmk7EhygHaHa?rs=1&pid=ImgDetMain"
  scheduler_icon_path = "scheduler.png"
  urlretrieve(scheduler_URL, scheduler_icon_path)
  scheduler = Custom("\nScheduler",scheduler_icon_path, scheduler_label="scheduler", fontsize="12")

# Create a csv icon
  csv_URL = "https://blog.paymaster.com/wp-content/uploads/2016/09/145257200-csv-sm3.png"
  csv_icon_path = "csv.png"
  urlretrieve(csv_URL, csv_icon_path)
  csv = Custom("\nCSV",csv_icon_path, csv_label="CSV", fontsize="12")

# Create a csv icon
  csv_URL = "https://blog.paymaster.com/wp-content/uploads/2016/09/145257200-csv-sm3.png"
  csv_icon_path = "csv.png"
  urlretrieve(csv_URL, csv_icon_path)
  csv2 = Custom("\nCSV",csv_icon_path, csv_label="CSV", fontsize="12")

# Create a playwright icon
  scrappyengine_URL = "https://th.bing.com/th/id/OIP.rk5drZx9NL79Fa7wmFGBKwHaGY?rs=1&pid=ImgDetMain"
  scrappyengine_icon_path = "scrappyengine.png"
  urlretrieve(scrappyengine_URL, scrappyengine_icon_path)
  scrappyengine = Custom("\nScrappy Engine",scrappyengine_icon_path, scrappyengine_label="Scrappyengine", fontsize="12")

# Create a docker icon
  docker_URL = "https://th.bing.com/th/id/OIP.dEgEQ0JBlwn323Q_i0spsgAAAA?rs=1&pid=ImgDetMain"
  docker_icon_path = "docker.png"
  urlretrieve(docker_URL, docker_icon_path)
  docker = Custom("\nDocker",docker_icon_path, docker_label="docker", fontsize="12")

# Create a S3 icon
  s3_URL = "https://www.hava.io/hubfs/documentation/Icons/AWS_S3_Bucket.png"
  s3_icon_path = "s3.png"
  urlretrieve(s3_URL, s3_icon_path)
  s3 = Custom("\nAWS S3",s3_icon_path, s3_label="AWS S3", fontsize="12")

# Create a SQL icon
  sql_URL = "https://static-00.iconduck.com/assets.00/sql-database-generic-icon-1521x2048-d0vdpxpg.png"
  sql_icon_path = "sql.png"
  urlretrieve(sql_URL, sql_icon_path)
  sql = Custom("\nDatabase Operation",sql_icon_path, sql_label="SQL", fontsize="12")

# Create a text icon
  text_URL = "https://th.bing.com/th/id/OIP.9uTcyTzKHT3V4WsoGjdkSwHaHa?rs=1&pid=ImgDetMain"
  text_icon_path = "text.png"
  urlretrieve(text_URL, text_icon_path)
  text = Custom("\nText Files",text_icon_path, text_label="Text", fontsize="12")

# Create a Snowflake icon
  snowflake_URL = "https://th.bing.com/th/id/OIP.7H00lNGgRCpsdbvkf9WZQAHaHa?rs=1&pid=ImgDetMain"
  snowflake_icon_path = "snowflake.png"
  urlretrieve(snowflake_URL, snowflake_icon_path)
  snowflake = Custom("\nSnowflake",snowflake_icon_path, snowflake_label="Snowflake", fontsize="12")


# Create a internet icon
  internet_URL = "https://th.bing.com/th/id/OIP.vAekblfhJBypJhXhfyQNnAHaH-?rs=1&pid=ImgDetMain"
  internet_icon_path = "internet.png"
  urlretrieve(internet_URL, internet_icon_path)
  internet = Custom("\nInternet",internet_icon_path, internet_label="Internet", fontsize="12")




  #Links
  scrappyengine >> scheduler
  scrappyengine >> Edge(label="Playwright\nMiddleware")>> playwright
  playwright >> internet
  scrappyengine >> Edge(label="Spider Middleware") >> spyder
  csv >> sql
  text >> sql
  sql >> s3
  sql  >> Edge(label="SQLAlchemy")>> snowflake

  pdf >> grobid
  docker >> grobid
  grobid >> Edge(label="XML Parsing")>>  xml
  xml >> csv2
  csv2 >> sql
  xml >> text
  spyder >> csv
  pipeline >> scrappyengine

print
# Out:
# Warning: node 'd7d54b3410ac4bc3b9756d98cd08cb70', graph 'Assignment 2 diagram' size too small for label
# Warning: node '0edd93468e89418d8e0b979af7a107a0', graph 'Assignment 2 diagram' size too small for label
# Warning: Orthogonal edges do not currently handle edge labels. Try using xlabels.
